# %% [markdown]
# # Linear Regression in One Variable
#
# Cost: Euclidean norm
#
# Optimizer: Gradient descent
#
# Libraries:
#            - Numpy for Math
#            - Pandas for Data handling
#            - Matplotlib for Plotting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('ex1data1.txt')
x = data.iloc[:,0]
y = data.iloc[:,1]
m = len(y)

# %%
plt.scatter(x,y,c='#ff0000',marker='o')
plt.title('Data Points',fontsize=24)
plt.xlabel('$x$',fontsize=24)
plt.ylabel('$y$',fontsize=24)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
x = x[:,np.newaxis]
y = y[:,np.newaxis]
theta = np.zeros([2,1])
num_iter = 1500
alpha = 0.01

ones = np.ones((m,1))
x = np.hstack((ones,x))

# %% [markdown]
# Cost: $ J(\theta) = \Vert X \theta - y \Vert^2 $

# %%
def computeCost(x,y,theta):
    temp = np.dot(x,theta) - y
    return np.sum(np.power(temp,2))/(2*m)

J = computeCost(x,y,theta)
print(J)
# Out:
# 30.79495785534583

# %%
def gradientDescent(x,y,theta,alpha,num_iter):
    for _ in range(num_iter):
        temp = np.dot(x,theta) - y
        temp = np.dot(x.T,temp)
        theta = theta - (alpha/m)*temp
    return theta

theta = gradientDescent(x,y,theta,alpha,num_iter)
print(theta)
# Out:
# [[-3.92643901]
#  [ 1.1849957 ]]

# %%
J = computeCost(x,y,theta)
print(J)
# Out:
# 3.466993148044392

# %%
plt.scatter(x[:,1], y,c='#ff0000',marker='o')
plt.plot(x[:,1],np.dot(x,theta),c='#00ff00')
plt.title('Data Points',fontsize=24)
plt.xlabel('$x$',fontsize=24)
plt.ylabel('$y$',fontsize=24)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
